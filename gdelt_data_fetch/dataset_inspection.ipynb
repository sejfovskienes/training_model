# %%
import pandas as pd

# %%
path = r'C:\Users\User\dev\training_model\gdelt_data_fetch\gdelt_gold_filtered\20140101_gold_filtered.csv'

df = pd.read_csv(path)

df.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0      281451768  20130101     201301  2013     2013.0027        AFG
# 1      281451769  20130101     201301  2013     2013.0027        AFG
# 2      281453925  20131231     201312  2013     2013.9890        MIL
# 3      281454318  20140101     201401  2014     2014.0027        NaN
# 4      281455036  20140101     201401  2014     2014.0027        NaN
#
#     Actor1Name Actor1CountryCode  Actor1KnownGroupCode Actor1EthnicCode  ...  \
# 0  AFGHANISTAN               AFG                   NaN              NaN  ...
# 1  AFGHANISTAN               AFG                   NaN              NaN  ...
# 2    BATTALION               NaN                   NaN              NaN  ...
# 3          NaN               NaN                   NaN              NaN  ...
# 4          NaN               NaN                   NaN              NaN  ...
#
#   Actor2Geo_FeatureID ActionGeo_Type                    ActionGeo_FullName  \
# 0            -1561728              4       Brisbane, Queensland, Australia
# 1            -1561728              4       Brisbane, Queensland, Australia
# 2                 NaN              4              Dhaka, Dhaka, Bangladesh
# 3             1669583              3  West Wendover, Nevada, United States
# 4            -2092174              4            Mumbai, Maharashtra, India
#
#   ActionGeo_CountryCode  ActionGeo_ADM1Code ActionGeo_Lat ActionGeo_Long  \
# 0                    AS                AS04      -27.5000       153.0170
# 1                    AS                AS04      -27.5000       153.0170
# 2                    BG                BG81       23.7231        90.4086
# 3                    US                USNV       40.7391      -114.0730
# 4                    IN                IN16       18.9750        72.8258
#
#   ActionGeo_FeatureID  DATEADDED  \
# 0            -1561728   20140101
# 1            -1561728   20140101
# 2            -2737683   20140101
# 3             1669583   20140101
# 4            -2092174   20140101
#
#                                            SOURCEURL
# 0  http://www.enca.com/world/soldier-loses-life-s...
# 1  http://www.enca.com/world/soldier-loses-life-s...
# 2  http://www.dhakatribune.com/crime/2014/jan/02/...
# 3  http://elkodaily.com/mining/students-learn-min...
# 4  http://www.dnaindia.com/mumbai/report-mumbai-m...
#
# [5 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GLOBALEVENTID          133 non-null    int64
#  1   SQLDATE                133 non-null    int64
#  2   MonthYear              133 non-null    int64
#  3   Year                   133 non-null    int64
#  4   FractionDate           133 non-null    float64
#  5   Actor1Code             116 non-null    object
#  6   Actor1Name             116 non-null    object
#  7   Actor1CountryCode      61 non-null     object
#  8   Actor1KnownGroupCode   0 non-null      float64
#  9   Actor1EthnicCode       3 non-null      object
#  10  Actor1Religion1Code    9 non-null      object
#  11  Actor1Religion2Code    2 non-null      object
#  12  Actor1Type1Code        51 non-null     object
#  13  Actor1Type2Code        1 non-null      object
#  14  Actor1Type3Code        0 non-null      float64
#  15  Actor2Code             78 non-null     object
#  16  Actor2Name             78 non-null     object
#  17  Actor2CountryCode      43 non-null     object
#  18  Actor2KnownGroupCode   0 non-null      float64
#  19  Actor2EthnicCode       0 non-null      float64
#  20  Actor2Religion1Code    1 non-null      object
#  21  Actor2Religion2Code    0 non-null      float64
#  22  Actor2Type1Code        37 non-null     object
#  23  Actor2Type2Code        1 non-null      object
#  24  Actor2Type3Code        0 non-null      float64
#  25  IsRootEvent            133 non-null    int64
#  26  EventCode              133 non-null    int64
#  27  EventBaseCode          133 non-null    int64
#  28  EventRootCode          133 non-null    int64
#  29  QuadClass              133 non-null    int64
#  30  GoldsteinScale         133 non-null    float64
#  31  NumMentions            133 non-null    int64
#  32  NumSources             133 non-null    int64
#  33  NumArticles            133 non-null    int64
#  34  AvgTone                133 non-null    float64
#  35  Actor1Geo_Type         133 non-null    int64
#  36  Actor1Geo_FullName     114 non-null    object
#  37  Actor1Geo_CountryCode  114 non-null    object
#  38  Actor1Geo_ADM1Code     114 non-null    object
#  39  Actor1Geo_Lat          114 non-null    float64
#  40  Actor1Geo_Long         114 non-null    float64
#  41  Actor1Geo_FeatureID    114 non-null    object
#  42  Actor2Geo_Type         133 non-null    int64
#  43  Actor2Geo_FullName     77 non-null     object
#  44  Actor2Geo_CountryCode  77 non-null     object
#  45  Actor2Geo_ADM1Code     77 non-null     object
#  46  Actor2Geo_Lat          77 non-null     float64
#  47  Actor2Geo_Long         77 non-null     float64
#  48  Actor2Geo_FeatureID    77 non-null     object
#  49  ActionGeo_Type         133 non-null    int64
#  50  ActionGeo_FullName     130 non-null    object
#  51  ActionGeo_CountryCode  130 non-null    object
#  52  ActionGeo_ADM1Code     130 non-null    object
#  53  ActionGeo_Lat          130 non-null    float64
#  54  ActionGeo_Long         130 non-null    float64
#  55  ActionGeo_FeatureID    130 non-null    object
#  56  DATEADDED              133 non-null    int64
#  57  SOURCEURL              133 non-null    object
# dtypes: float64(15), int64(16), object(27)
# memory usage: 60.4+ KB

# %%
df.columns
# Out:
# Index(['GLOBALEVENTID', 'SQLDATE', 'MonthYear', 'Year', 'FractionDate',
#        'Actor1Code', 'Actor1Name', 'Actor1CountryCode', 'Actor1KnownGroupCode',
#        'Actor1EthnicCode', 'Actor1Religion1Code', 'Actor1Religion2Code',
#        'Actor1Type1Code', 'Actor1Type2Code', 'Actor1Type3Code', 'Actor2Code',
#        'Actor2Name', 'Actor2CountryCode', 'Actor2KnownGroupCode',
#        'Actor2EthnicCode', 'Actor2Religion1Code', 'Actor2Religion2Code',
#        'Actor2Type1Code', 'Actor2Type2Code', 'Actor2Type3Code', 'IsRootEvent',
#        'EventCode', 'EventBaseCode', 'EventRootCode', 'QuadClass',
#        'GoldsteinScale', 'NumMentions', 'NumSources', 'NumArticles', 'AvgTone',
#        'Actor1Geo_Type', 'Actor1Geo_FullName', 'Actor1Geo_CountryCode',
#        'Actor1Geo_ADM1Code', 'Actor1Geo_Lat', 'Actor1Geo_Long',
#        'Actor1Geo_FeatureID', 'Actor2Geo_Type', 'Actor2Geo_FullName',
#        'Actor2Geo_CountryCode', 'Actor2Geo_ADM1Code', 'Actor2Geo_Lat',
#        'Actor2Geo_Long', 'Actor2Geo_FeatureID', 'ActionGeo_Type',
#        'ActionGeo_FullName', 'ActionGeo_CountryCode', 'ActionGeo_ADM1Code',
#        'ActionGeo_Lat', 'ActionGeo_Long', 'ActionGeo_FeatureID', 'DATEADDED',
#        'SOURCEURL'],
#       dtype='object')

# %%
df['SOURCEURL']
# Out:
# 0      http://www.enca.com/world/soldier-loses-life-s...
# 1      http://www.enca.com/world/soldier-loses-life-s...
# 2      http://www.dhakatribune.com/crime/2014/jan/02/...
# 3      http://elkodaily.com/mining/students-learn-min...
# 4      http://www.dnaindia.com/mumbai/report-mumbai-m...
#                              ...
# 128    http://www.tuscaloosanews.com/article/20131231...
# 129    http://www.tuscaloosanews.com/article/20131231...
# 130    http://townhall.com/columnists/rachelmarsden/2...
# 131    http://townhall.com/columnists/rachelmarsden/2...
# 132    http://townhall.com/columnists/rachelmarsden/2...
# Name: SOURCEURL, Length: 133, dtype: object
